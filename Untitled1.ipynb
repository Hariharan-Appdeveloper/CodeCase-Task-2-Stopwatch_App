# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
from google.colab import drive

# %%
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dataset = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/database.csv")

# %%
dataset
# Out:
#              Date      Time  Latitude  Longitude        Type   Depth  \
# 0      01/02/1965  13:44:18   19.2460   145.6160  Earthquake  131.60
# 1      01/04/1965  11:29:49    1.8630   127.3520  Earthquake   80.00
# 2      01/05/1965  18:05:58  -20.5790  -173.9720  Earthquake   20.00
# 3      01/08/1965  18:49:43  -59.0760   -23.5570  Earthquake   15.00
# 4      01/09/1965  13:32:50   11.9380   126.4270  Earthquake   15.00
# ...           ...       ...       ...        ...         ...     ...
# 23407  12/28/2016  08:22:12   38.3917  -118.8941  Earthquake   12.30
# 23408  12/28/2016  09:13:47   38.3777  -118.8957  Earthquake    8.80
# 23409  12/28/2016  12:38:51   36.9179   140.4262  Earthquake   10.00
# 23410  12/29/2016  22:30:19   -9.0283   118.6639  Earthquake   79.00
# 23411  12/30/2016  20:08:28   37.3973   141.4103  Earthquake   11.94
#
#        Depth Error  Depth Seismic Stations  Magnitude Magnitude Type  ...  \
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23412 entries, 0 to 23411
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Date                        23412 non-null  object
#  1   Time                        23412 non-null  object
#  2   Latitude                    23412 non-null  float64
#  3   Longitude                   23412 non-null  float64
#  4   Type                        23412 non-null  object
#  5   Depth                       23412 non-null  float64
#  6   Depth Error                 4461 non-null   float64
#  7   Depth Seismic Stations      7097 non-null   float64
#  8   Magnitude                   23412 non-null  float64
#  9   Magnitude Type              23409 non-null  object
#  10  Magnitude Error             327 non-null    float64
#  11  Magnitude Seismic Stations  2564 non-null   float64
#  12  Azimuthal Gap               7299 non-null   float64
# ...

# %%
dataset.describe()
# Out:
#            Latitude     Longitude         Depth  Depth Error  \
# count  23412.000000  23412.000000  23412.000000  4461.000000
# mean       1.679033     39.639961     70.767911     4.993115
# std       30.113183    125.511959    122.651898     4.875184
# min      -77.080000   -179.997000     -1.100000     0.000000
# 25%      -18.653000    -76.349750     14.522500     1.800000
# 50%       -3.568500    103.982000     33.000000     3.500000
# 75%       26.190750    145.026250     54.000000     6.300000
# max       86.005000    179.998000    700.000000    91.295000
#
#        Depth Seismic Stations     Magnitude  Magnitude Error  \
# count             7097.000000  23412.000000       327.000000
# mean               275.364098      5.882531         0.071820
# std                162.141631      0.423066         0.051466
# min                  0.000000      5.500000         0.000000
# 25%                146.000000      5.600000         0.046000
# ...

# %%
dataset.columns
# Out:
# Index(['Date', 'Time', 'Latitude', 'Longitude', 'Type', 'Depth', 'Depth Error',
#        'Depth Seismic Stations', 'Magnitude', 'Magnitude Type',
#        'Magnitude Error', 'Magnitude Seismic Stations', 'Azimuthal Gap',
#        'Horizontal Distance', 'Horizontal Error', 'Root Mean Square', 'ID',
#        'Source', 'Location Source', 'Magnitude Source', 'Status'],
#       dtype='object')

# %%
data = dataset[['Time','Date','Latitude','Longitude','Depth','Magnitude','Status']]

# %%
data
# Out:
#            Time        Date  Latitude  Longitude   Depth  Magnitude     Status
# 0      13:44:18  01/02/1965   19.2460   145.6160  131.60        6.0  Automatic
# 1      11:29:49  01/04/1965    1.8630   127.3520   80.00        5.8  Automatic
# 2      18:05:58  01/05/1965  -20.5790  -173.9720   20.00        6.2  Automatic
# 3      18:49:43  01/08/1965  -59.0760   -23.5570   15.00        5.8  Automatic
# 4      13:32:50  01/09/1965   11.9380   126.4270   15.00        5.8  Automatic
# ...         ...         ...       ...        ...     ...        ...        ...
# 23407  08:22:12  12/28/2016   38.3917  -118.8941   12.30        5.6   Reviewed
# 23408  09:13:47  12/28/2016   38.3777  -118.8957    8.80        5.5   Reviewed
# 23409  12:38:51  12/28/2016   36.9179   140.4262   10.00        5.9   Reviewed
# 23410  22:30:19  12/29/2016   -9.0283   118.6639   79.00        6.3   Reviewed
# 23411  20:08:28  12/30/2016   37.3973   141.4103   11.94        5.5   Reviewed
#
# ...

# %%
data.head(15)
# Out:
#         Time        Date  Latitude  Longitude  Depth  Magnitude     Status
# 0   13:44:18  01/02/1965    19.246    145.616  131.6        6.0  Automatic
# 1   11:29:49  01/04/1965     1.863    127.352   80.0        5.8  Automatic
# 2   18:05:58  01/05/1965   -20.579   -173.972   20.0        6.2  Automatic
# 3   18:49:43  01/08/1965   -59.076    -23.557   15.0        5.8  Automatic
# 4   13:32:50  01/09/1965    11.938    126.427   15.0        5.8  Automatic
# 5   13:36:32  01/10/1965   -13.405    166.629   35.0        6.7  Automatic
# 6   13:32:25  01/12/1965    27.357     87.867   20.0        5.9  Automatic
# 7   23:17:42  01/15/1965   -13.309    166.212   35.0        6.0  Automatic
# 8   11:32:37  01/16/1965   -56.452    -27.043   95.0        6.0  Automatic
# 9   10:43:17  01/17/1965   -24.563    178.487  565.0        5.8  Automatic
# 10  20:57:41  01/17/1965    -6.807    108.988  227.9        5.9  Automatic
# ...

# %%
import datetime
import time

# %%
timestamp = []
for d, t in zip(data['Date'], data['Time']):
    try:
        ts = datetime.datetime.strptime(d+' '+t, '%m/%d/%Y %H:%M:%S')
        timestamp.append(time.mktime(ts.timetuple()))
    except ValueError:
        # print('ValueError')
        timestamp.append('ValueError')

# %%
timeStamp = pd.Series(timestamp)
data['Timestamp'] = timeStamp.values
# Out:
# <ipython-input-15-dc94aa5dafbe>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Timestamp'] = timeStamp.values

# %%
time_data=data.drop(['Date','Time'],axis=True)

# %%
time_data=time_data.head(25)
time_data
# Out:
#     Latitude  Longitude  Depth  Magnitude     Status    Timestamp
# 0     19.246    145.616  131.6        6.0  Automatic -157630542.0
# 1      1.863    127.352   80.0        5.8  Automatic -157465811.0
# 2    -20.579   -173.972   20.0        6.2  Automatic -157355642.0
# 3    -59.076    -23.557   15.0        5.8  Automatic -157093817.0
# 4     11.938    126.427   15.0        5.8  Automatic -157026430.0
# 5    -13.405    166.629   35.0        6.7  Automatic -156939808.0
# 6     27.357     87.867   20.0        5.9  Automatic -156767255.0
# 7    -13.309    166.212   35.0        6.0  Automatic -156472938.0
# 8    -56.452    -27.043   95.0        6.0  Automatic -156428843.0
# 9    -24.563    178.487  565.0        5.8  Automatic -156345403.0
# 10    -6.807    108.988  227.9        5.9  Automatic -156308539.0
# 11    -2.608    125.952   20.0        8.2  Automatic -155778523.0
# 12    54.636    161.703   55.0        5.5  Automatic -155312670.0
# ...

# %%
splitted = data['Date'].str.split('/',expand=True)
data['Day']=splitted[0]
data['Month']=splitted[1]
data['Year']=splitted[2]
data.drop('Date', axis=1,inplace=True)
# Out:
# <ipython-input-68-816b2b560259>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Day']=splitted[0]
# <ipython-input-68-816b2b560259>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['Month']=splitted[1]
# <ipython-input-68-816b2b560259>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
data
# Out:
#            Time  Latitude  Longitude   Depth  Magnitude     Status  \
# 0      13:44:18   19.2460   145.6160  131.60        6.0  Automatic
# 1      11:29:49    1.8630   127.3520   80.00        5.8  Automatic
# 2      18:05:58  -20.5790  -173.9720   20.00        6.2  Automatic
# 3      18:49:43  -59.0760   -23.5570   15.00        5.8  Automatic
# 4      13:32:50   11.9380   126.4270   15.00        5.8  Automatic
# ...         ...       ...        ...     ...        ...        ...
# 23407  08:22:12   38.3917  -118.8941   12.30        5.6   Reviewed
# 23408  09:13:47   38.3777  -118.8957    8.80        5.5   Reviewed
# 23409  12:38:51   36.9179   140.4262   10.00        5.9   Reviewed
# 23410  22:30:19   -9.0283   118.6639   79.00        6.3   Reviewed
# 23411  20:08:28   37.3973   141.4103   11.94        5.5   Reviewed
#
#           Timestamp Day Month  Year
# 0      -157630542.0  01    02  1965
# 1      -157465811.0  01    04  1965
# 2      -157355642.0  01    05  1965
# ...

# %%
# !pip install basemap

# %%
from mpl_toolkits.basemap import Basemap

# %%
map = Basemap(projection='mbtfpq',lon_0=0,resolution='c')
longitude = data["Longitude"].tolist()
latitude = data["Latitude"].tolist()
x,y = map(longitude,latitude)

# %%
fig=plt.figure(figsize=(12,9))
plt.title("Affected Areas")
map.plot(x, y, "o", markersize = 2, color = 'red')
map.fillcontinents(color='green',lake_color='aqua')
map.drawcoastlines()
map.drawmapboundary()
map.drawcountries()
plt.show()

# %%
plt.figure(figsize=(20, 5))
bar_grph = data.groupby('Year').mean()['Depth']
bar_grph.plot.bar(color="red")
plt.show()
# Out:
# <ipython-input-95-73261113ff92>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   bar_grph = data.groupby('Year').mean()['Depth']

# %%
plt.figure(figsize=(35, 10))
sb.lineplot(data=data,x='Year',y='Magnitude',color="coral")
plt.show()

# %%
plt.figure(figsize=(10,5-))
sb.lineplot(data=data,x="Magnitude",y="Depth")
plt.show()

# %%
plt.figure(figsize=(10, 8))
sb.scatterplot(data=data,x='Latitude',y='Longitude',hue='Magnitude')
plt.show()

# %%
sb.boxplot(data,x="Magnitude",palette="Blues")
# Out:
# <Axes: xlabel='Magnitude'>

# %%
sb.jointplot(dataset,y="Depth",x="Magnitude",kind="hex",color="red")
